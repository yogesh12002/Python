# %% [markdown]
# **IF STATEMENT**

# %%
age = 20
if age>=18:
  print("adult")
# Out:
# adult

# %% [markdown]
# IF ELSE STATEMENT

# %%
age = 20
if age>=18:
  print("adult")
else:
    print("not adult")
# Out:
# adult

# %% [markdown]
# IF ELSIF ELSE STATEMENT

# %%
marks = 70
if marks>=90:
  print("Grade A")
elif marks>=80:
  print("Grade B")
elif marks>=70:
  print("Grade C")
else :
  print("Fail")
# Out:
# Grade C

# %% [markdown]
# FOR LOOP

# %%
n =4
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# WHILE LOOP

# %%
count = 0
while count < 5:
    count += 1
    print(count)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for character in "CODE":
    print(character)
# Out:
# C
# O
# D
# E

# %%
correct_pin= "1234"
attempt_left = 3


  entered_pin = input("enter your pin")
  if entered_pin==correct_pin:
    print("pin accepted")
  else :
      attempt_left -=1
      print("pin rejected")
      if attempt_left == 0:
            print("System locked")
            break
# Out:
#   File "/tmp/ipykernel_2879/3595403322.py", line 5
#     entered_pin = input("enter your pin")
#     ^
# IndentationError: unexpected indent

# %%
num1 = int(input("enter the first number: "))
operator = input("enter the operator (+, -, *, /): ")
num2 = int(input("enter the second number: "))

if operator == "+":
  print(num1 + num2)
elif operator == "-":
  print(num1 - num2)
elif operator == "*":
  print(num1 * num2)
elif operator == "/":
  print(num1 / num2)
else:
  print("invalid operator")
# Out:
# enter the first number: 5
# enter the operator (+, -, *, /): -
# enter the second number: 98765
# -98760

# %% [markdown]
# **Assignement - 2**

# %%
text = "hello PYTHON world"

print(text.upper())  # 'HELLO PYTHON WORLD'
print(text.lower())  # 'hello python world'
print(text.capitalize())  # 'Hello python world'
print(text.title())  # 'Hello Python World'
print(text.swapcase())  # 'HELLO python WORLD'
# Out:
# HELLO PYTHON WORLD
# hello python world
# Hello python world
# Hello Python World
# HELLO python WORLD

# %%
msg = "python programming with python"

print(msg.find("python"))  # Output: 0
print(msg.rfind("python"))  # Output: 24
print(msg.count("python"))  # Output: 2
# Out:
# 0
# 24
# 2

# %%
code = "Python123"

print(code.isalpha())  # False (Kyunki numbers bhi hain)
print(code.isalnum())  # True
print(code.startswith("Py"))  # True
print(code.endswith("123"))  # True
# Out:
# False
# True
# True
# True
